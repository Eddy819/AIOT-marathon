# %% [markdown]
# # 作業一

# %% [markdown]
# 將此映像檔下載至電腦 alpine

# %%
from IPython.display import Image

# %%
Image("./HW1.png",width=400,height=400)

# %% [markdown]
# # 作業二

# %% [markdown]
# 使用下載的映像檔建立容器，並選定本機中的一個資料夾與容器中的資料夾做連結，在本機與容器做連結的資料夾裡建立一個檔案，使用指令進到容器內，查看與外部連結的資料夾，即可看到剛剛在本機建立的檔案

# %%
Image("./HW2.png",width=800,height=400)
