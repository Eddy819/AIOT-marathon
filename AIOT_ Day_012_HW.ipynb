# %% [markdown]
# # 作業一
# * 實際練習 /sys/class/gpio 啟動 gpio，設定 gpio 接腳的狀態，並且卸載所啟動的 gpio。同時觀察卸載之後的 gpio 接腳，繼續送設定狀態的資料，將會發生什麼樣的狀態。

# %%
from IPython.display import Image

# %% [markdown]
# * 將 GPIO 啟動，可以用 sysfs 控制 echo 4 > /sys/class/gpio/export
#
# * 設定 GPIO4 為輸出 echo out > /sys/class/gpio/gpio4/direction
#
# * 設定 GPIO4 輸出值為 1 (0：低電位，1：高電位) echo 1 > /sys/class/gpio/gpio4/value
#
# * 使用 debugfs 察看目前 GPIO 狀態。 sudo cat /sys/kernel/debug/gpio

# %%
Image("./HW1-1.png",width=600,height=400)

# %% [markdown]
# * 將 GPIO4 卸載，不用 sysfs 控制 echo 4 > /sys/class/gpio/unexport
#
# * 設定 GPIO4 輸出值為 0 (0：低電位，1：高電位) echo 0 > /sys/class/gpio/gpio4/value

# %%
Image("./HW1-2.png",width=600,height=400)

# %% [markdown]
# # 作業二
# * 使用 raspi-config 啟動 i2c，觀察 gpio2 以及 gpio3 的變化，透過 /sys/kernel/debug/gpio 觀察改變的情形，嘗試重新做一次作業1，針對 gpio2 以及 gpio3 操作，觀察在 i2c 啟動的狀態下，gpio2 以及 gpio3 相對 gpio4 有何不同。

# %%
Image("./HW2-1.png",width=600,height=400)

# %%
Image("./HW2-2.png",width=600,height=400)

# %%
Image("./HW2-3.png",width=600,height=400)

# %% [markdown]
# Q: 觀察在 i2c 啟動的狀態下，gpio2 以及 gpio3 相對 gpio4 有何不同
#
# A: 無任何不同

# %% [markdown]
# # 作業三
# * 使用 raspi-config 啟動 spi，觀察 gpio 各接腳的變化狀態，嘗試將 spi 關閉之後，透過 /sys/kernel/debug/gpio，觀察可以使用 gpio 數量的變化情形。

# %%
Image("./HW3-1.png",width=600,height=400)

# %%
Image("./HW3-2.png",width=600,height=400)

# %%
Image("./HW3-3.png",width=600,height=400)

# %%
Image("./HW3-4.png",width=600,height=400)
